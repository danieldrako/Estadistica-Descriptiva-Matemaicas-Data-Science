# %% [markdown]
# <a href="https://colab.research.google.com/github/danieldrako/Estadistica-Descriptiva-Matemaicas-Data-Science/blob/main/03Visualizaciones.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Visualizaciones
# Cargamos datos del datasetr `iris`
#
# ![How-to-Visualize-your-Data-with-Charts-and-Graphs.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Se puede visualizar esta pagina para mas información sobre el tipo de visualizaciones
#
# https://datavizproject.com/

# %%
import pandas as pd 
import seaborn as sns

iris = sns.load_dataset('iris')

iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ###Scatterplot

# %%
sns.set(rc = {'figure.figsize':(12,10)})
sns.scatterplot(data=iris, x = 'sepal_length', y = 'petal_length', hue = 'species')

# %% [markdown]
#  ### Joint plot

# %%
sns.jointplot(data=iris, x = 'sepal_length', y = 'petal_length', hue = 'species', height=10)

# %% [markdown]
# ###box plot

# %%
sns.boxplot(x = 'species', y = 'sepal_length', data = iris)

# %% [markdown]
# ###Barplot

# %%
sns.barplot(x = 'species', y = 'sepal_length', data = iris)

# %%
sns.pairplot(iris, hue='species', palette='dark', diag_kind='kde')

# %%
]
